# %%
import pandas as pd

# %%
zomato = pd.read_csv("C:/Users/misvi/Downloads/Zomato_Dataset.csv")

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %% [raw]
# Features:
#
# ID: Unique identifier for each delivery.
# Delivery_person_ID: Unique identifier for each delivery person.
# Delivery_person_Age: Age of the delivery person.
# Delivery_person_Ratings: Ratings assigned to the delivery person.
# Restaurant_latitude: Latitude of the restaurant.
# Restaurant_longitude: Longitude of the restaurant.
# Delivery_location_latitude: Latitude of the delivery location.
# Delivery_location_longitude: Longitude of the delivery location.
# Order_Date: Date of the order.
# Time_Ordered: Time the order was placed.
# Time_Order_picked: Time the order was picked up for delivery.
# Weather_conditions: Weather conditions at the time of delivery.
# Road_traffic_density: Density of road traffic during delivery.
# Vehicle_condition: Condition of the delivery vehicle.
# Type_of_order: Type of order (e.g., dine-in, takeaway, delivery).
# Type_of_vehicle: Type of vehicle used for delivery.
# Multiple_deliveries: Indicator of whether multiple deliveries were made in the same trip.
# Festival: Indicator of whether the delivery coincided with a festival.
# City: City where the delivery took place.
# Time_taken (min): Time taken for delivery in minutes.

# %%
zomato.isnull().sum() # identifying null values
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
zomato.shape
# Out:
# (45584, 20)

# %% [markdown]
# ## Missing null value imputation

# %% [markdown]
# ### Age

# %%
# Age
Delivery_person_Age = zomato['Delivery_person_Age'].median()   
print(Delivery_person_Age)
# Out:
# 30.0

# %%
zomato['Delivery_person_Age'] = zomato['Delivery_person_Age'].fillna(Delivery_person_Age)

# %% [markdown]
# ### Ratings

# %%
# Ratings
Delivery_person_Ratings = zomato['Delivery_person_Ratings'].median()
zomato['Delivery_person_Ratings'] = zomato['Delivery_person_Ratings'].fillna(Delivery_person_Ratings)

# %% [markdown]
# ### Weather_conditions

# %%
# Weather_conditions              
zomato['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: count, dtype: int64

# %%
# In weather condition, all the values are almost similiar weightage in data

# We will impute with normal weather condition i.e Sunny

# %%
zomato['Weather_conditions'] = zomato['Weather_conditions'].fillna('Sunny')
zomato['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Sunny         7898
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Name: count, dtype: int64

# %% [markdown]
# ### Road_traffic_density

# %%
## Road_traffic_density   
zomato['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %%
zomato['Road_traffic_density'] = zomato['Road_traffic_density'].fillna('Low')
zomato['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       16077
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %% [markdown]
# ### Multiple deliveries

# %%
zomato['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1.0    28151
# 0.0    14094
# 2.0     1985
# 3.0      361
# Name: count, dtype: int64

# %%
zomato[zomato['multiple_deliveries'] == 0.0] # Multiple deliveries can't be 0, it should be atleast 1
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 11     0x5795   RANCHIRES06DEL02                 31.0
# 16     0x3231      JAPRES16DEL03                 27.0
# 17     0x8bc0      SURRES15DEL03                 35.0
# 19     0x3c5e     PUNERES04DEL01                 23.0
# ...       ...                ...                  ...
# 45565  0x90c5      MUMRES20DEL03                 21.0
# 45573  0x59ae     PUNERES13DEL02                 30.0
# 45575  0xa333     CHENRES08DEL02                 37.0
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 3                          4.3            30.899584             75.809346
# 11                         4.7            23.357804             85.325146
# 16                         5.0            26.849596             75.800512
# 17                         4.3            21.160522             72.771477
# 19                         4.8            18.514210             73.838429
# ...                        ...                  ...                   ...
# 45565                      4.8            19.103249             72.846749
# 45573                      4.6            18.562450             73.916619
# 45575                      4.8            13.022394             80.242439
# 45579                      4.8            26.902328             75.794257
# 45581                      4.9            13.022394             80.242439
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 3                       30.919584                    75.829346  13-02-2022
# 11                      23.487804                    85.455146  10-03-2022
# 16                      26.879596                    75.830512  05-04-2022
# 17                      21.250522                    72.861477  12-03-2022
# 19                      18.624210                    73.948429  02-04-2022
# ...                           ...                          ...         ...
# 45565                   19.133249                    72.876749  19-03-2022
# 45573                   18.582450                    73.936619  01-04-2022
# 45575                   13.042394                    80.262439  05-04-2022
# 45579                   26.912328                    75.804257  24-03-2022
# 45581                   13.052394                    80.272439  11-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 3           09:20             09:30         Sandstorms                  Low
# 11          22:30             22:45         Sandstorms                  Low
# 16          20:35             20:40             Stormy                  Jam
# 17          23:20             23:30             Cloudy                  Low
# 19          23:35             23:45              Windy                  Low
# ...           ...               ...                ...                  ...
# 45565       22:15             22:20              Sunny                  Low
# 45573       0.375             09:15             Cloudy                  Low
# 45575       09:35             09:50         Sandstorms                  Low
# 45579       11:35             11:45              Windy                 High
# 45581       23:50          24:05:00             Cloudy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries  \
# 3                      0        Buffet        motorcycle                  0.0
# 11                     2          Meal  electric_scooter                  0.0
# 16                     0         Snack        motorcycle                  0.0
# 17                     1        Drinks           scooter                  0.0
# 19                     2        Buffet  electric_scooter                  0.0
# ...                  ...           ...               ...                  ...
# 45565                  2        Drinks        motorcycle                  0.0
# 45573                  0          Meal        motorcycle                  0.0
# 45575                  2        Drinks  electric_scooter                  0.0
# 45579                  1          Meal        motorcycle                  0.0
# 45581                  1        Drinks           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 3           No  Metropolitian                20
# 11          No  Metropolitian                26
# 16          No          Urban                18
# 17          No  Metropolitian                38
# 19          No          Urban                12
# ...        ...            ...               ...
# 45565       No  Metropolitian                22
# 45573       No  Metropolitian                20
# 45575       No  Metropolitian                20
# 45579       No  Metropolitian                32
# 45581       No  Metropolitian                16
#
# [14094 rows x 20 columns]

# %%
zomato['multiple_deliveries'] = zomato['multiple_deliveries'].replace({0.0:1.0})

# %%
# Missing value impute with 1 value

zomato['multiple_deliveries'] = zomato['multiple_deliveries'].fillna(1)

# %% [markdown]
# ### Festival

# %%
# Festival

zomato['Festival'].value_counts()
# Out:
# Festival
# No     44460
# Yes      896
# Name: count, dtype: int64

# %% [markdown]
# ### Mode imputation

# %%
zomato['Festival'].mode()
# Out:
# 0    No
# Name: Festival, dtype: object

# %%
# Mode imputation
Festival_mode = zomato['Festival'].mode()[0]
zomato['Festival'] = zomato['Festival'].fillna(Festival_mode)

# %%
zomato['Festival'].value_counts()
# Out:
# Festival
# No     44688
# Yes      896
# Name: count, dtype: int64

# %% [markdown]
# ### city

# %%
zomato['City'].value_counts()
# Out:
# City
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
City_mode = zomato['City'].mode()[0]
zomato['City'] = zomato['City'].fillna(City_mode)

# %%
### Now we will check the null counts

zomato.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Time ordered

# %%
## Time ordered is important column to get the order time window, for eg: morning, afternoon, evening, late evening

'09:20'.split(':')
# Out:
# ['09', '20']

# %%
def time_window(time_ordered):
    try:
        hour = int(time_ordered.split(':')[0])
    except:
        return 'Not defined'
        
    
    if hour>= 7 and hour<=12:
        return 'morning'
    elif hour>= 4 and hour< 7:
        return 'early morning'
    elif hour>12 and hour<=17:
        return 'afternoon'
    elif hour >17 and hour<= 22:
        return 'evening'
    elif hour> 22 and hour<=24:
        return 'late evening'
    elif hour>= 0 and hour<4:
        return 'late evening'

# %%
time_window('16:00')
# Out:
# 'afternoon'

# %%
zomato['Time_Orderd'] = zomato['Time_Orderd'].apply(time_window) # it is used to apply the given function to each row

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022     evening             22:10
# 1                    76.347589  13-02-2022   afternoon             15:05
# 2                    74.006619  04-03-2022   afternoon             17:40
# 3                    75.829346  13-02-2022     morning             09:30
# 4                    80.502929  14-02-2022     evening             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
zomato['Time_Orderd'].value_counts()
# Out:
# Time_Orderd
# evening         20783
# morning          7838
# afternoon        7075
# Not defined      5369
# late evening     4519
# Name: count, dtype: int64

# %% [markdown]
# ## Changing lattitude and longitude to distance

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\misvi\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\misvi\anaconda3\lib\site-packages (from geopy) (2.1)

# %%
from geopy.distance import geodesic

# %%
# installing geopy

# %%
zomato.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
# Function to calculate distance
def distance(each_row):
    restaurant_loc = (each_row['Restaurant_latitude'], each_row['Restaurant_longitude'])
    delivery_loc = (each_row['Delivery_location_latitude'], each_row['Delivery_location_longitude'])
    return geodesic(restaurant_loc, delivery_loc).kilometers

# Apply the function to create a new row 'Distance'
zomato['distance_km'] = zomato.apply(distance, axis=1) # we are applying it for all columns of dataframe, because we are using 4 columns

# %%
zomato.head(5)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# 0                    78.116106  12-02-2022     evening  ...
# 1                    76.347589  13-02-2022   afternoon  ...
# 2                    74.006619  04-03-2022   afternoon  ...
# 3                    75.829346  13-02-2022     morning  ...
# 4                    80.502929  14-02-2022     evening  ...
#
#   Weather_conditions Road_traffic_density Vehicle_condition  Type_of_order  \
# 0                Fog                  Jam                 2          Snack
# 1             Stormy                 High                 1           Meal
# 2         Sandstorms               Medium                 1         Drinks
# 3         Sandstorms                  Low                 0         Buffet
# 4                Fog                  Jam                 1          Snack
#
#   Type_of_vehicle multiple_deliveries  Festival           City  \
# 0      motorcycle                 3.0        No  Metropolitian
# 1      motorcycle                 1.0        No  Metropolitian
# 2         scooter                 1.0        No  Metropolitian
# 3      motorcycle                 1.0        No  Metropolitian
# 4         scooter                 1.0        No  Metropolitian
#
#   Time_taken (min)  distance_km
# 0               46    10.271464
# 1               23     6.229376
# 2               21    13.764306
# 3               20     2.927795
# 4               41    19.373484
#
# [5 rows x 21 columns]

# %% [markdown]
# In ```apply()```, axis=0 means applying the function column-wise, and axis=1 means applying the function row-wise.
# In ```drop()```, axis=0 means dropping rows, and axis=1 means dropping columns.

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# 0                    78.116106  12-02-2022     evening  ...
# 1                    76.347589  13-02-2022   afternoon  ...
# 2                    74.006619  04-03-2022   afternoon  ...
# 3                    75.829346  13-02-2022     morning  ...
# 4                    80.502929  14-02-2022     evening  ...
#
#   Weather_conditions Road_traffic_density Vehicle_condition  Type_of_order  \
# 0                Fog                  Jam                 2          Snack
# 1             Stormy                 High                 1           Meal
# 2         Sandstorms               Medium                 1         Drinks
# 3         Sandstorms                  Low                 0         Buffet
# 4                Fog                  Jam                 1          Snack
#
#   Type_of_vehicle multiple_deliveries  Festival           City  \
# 0      motorcycle                 3.0        No  Metropolitian
# 1      motorcycle                 1.0        No  Metropolitian
# 2         scooter                 1.0        No  Metropolitian
# 3      motorcycle                 1.0        No  Metropolitian
# 4         scooter                 1.0        No  Metropolitian
#
#   Time_taken (min)  distance_km
# 0               46    10.271464
# 1               23     6.229376
# 2               21    13.764306
# 3               20     2.927795
# 4               41    19.373484
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Dropping columns

# %%
zomato.drop(['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude', 'Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Order_picked'], 
            axis = 1, inplace = True)

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  distance_km
# 0                46    10.271464
# 1                23     6.229376
# 2                21    13.764306
# 3                20     2.927795
# 4                41    19.373484

# %% [markdown]
# ### Descriptive analysis

# %% [markdown]
# We are trying to summarizing the data through descriptive analysis

# %%
zomato.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition  \
# count         45584.000000             45584.000000       45584.000000
# mean             29.584525                 4.636546           1.023385
# std               5.696221                 0.327931           0.839055
# min              15.000000                 1.000000           0.000000
# 25%              25.000000                 4.600000           0.000000
# 50%              30.000000                 4.700000           1.000000
# 75%              34.000000                 4.800000           2.000000
# max              50.000000                 6.000000           3.000000
#
#        multiple_deliveries  Time_taken (min)   distance_km
# count         45584.000000      45584.000000  45584.000000
# mean              1.059385         26.293963     99.216342
# std               0.267766          9.384298   1100.033036
# min               1.000000         10.000000      1.463837
# 25%               1.000000         19.000000      4.654185
# 50%               1.000000         26.000000      9.247098
# 75%               1.000000         32.000000     13.740932
# max               3.000000         54.000000  19709.575543

# %% [markdown]
# **Observation** in distance_km, we can observe that mean is 99 Km, and median is 9.24 Km. It is due to outlier present in data ( look at max value)

# %%
zomato[zomato['distance_km']>50]
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Time_Orderd  \
# 83                    34.0                      4.7  Not defined
# 274                   32.0                      4.7      evening
# 280                   30.0                      4.7  Not defined
# 416                   30.0                      4.7  Not defined
# 525                   30.0                      4.7  Not defined
# ...                    ...                      ...          ...
# 44924                 30.0                      4.9      evening
# 45011                 30.0                      4.7  Not defined
# 45099                 30.0                      4.7  Not defined
# 45173                 30.0                      4.0      evening
# 45495                 30.0                      4.7  Not defined
#
#       Weather_conditions Road_traffic_density  Vehicle_condition  \
# 83            Sandstorms                  Low                  1
# 274           Sandstorms                  Jam                  2
# 280               Stormy                  Jam                  2
# 416                Sunny                  Low                  3
# 525                Sunny                  Low                  3
# ...                  ...                  ...                ...
# 44924                Fog                  Low                  1
# 45011              Sunny                  Low                  3
# 45099              Windy                  Jam                  2
# 45173         Sandstorms                  Low                  0
# 45495              Sunny                  Low                  3
#
#       Type_of_order   Type_of_vehicle  multiple_deliveries Festival  \
# 83           Drinks           scooter                  1.0       No
# 274            Meal           scooter                  1.0       No
# 280            Meal           scooter                  1.0       No
# 416           Snack           scooter                  1.0       No
# 525          Buffet           scooter                  1.0       No
# ...             ...               ...                  ...      ...
# 44924        Buffet        motorcycle                  1.0       No
# 45011        Drinks  electric_scooter                  1.0       No
# 45099          Meal           scooter                  1.0       No
# 45173        Drinks        motorcycle                  1.0       No
# 45495          Meal           scooter                  1.0       No
#
#                 City  Time_taken (min)   distance_km
# 83     Metropolitian                15   6019.211231
# 274    Metropolitian                31   6018.501935
# 280            Urban                12  16626.050016
# 416    Metropolitian                20  17753.279986
# 525    Metropolitian                16  17135.952470
# ...              ...               ...           ...
# 44924  Metropolitian                15   4400.319819
# 45011  Metropolitian                30   4096.899846
# 45099          Urban                19  16575.776501
# 45173  Metropolitian                34   5866.143331
# 45495  Metropolitian                24  17357.914556
#
# [431 rows x 13 columns]

# %%
zomato['distance_km'] = zomato['distance_km'].where(zomato['distance_km'] <= 50, zomato['distance_km'].median())

# %%
zomato.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition  \
# count         45584.000000             45584.000000       45584.000000
# mean             29.584525                 4.636546           1.023385
# std               5.696221                 0.327931           0.839055
# min              15.000000                 1.000000           0.000000
# 25%              25.000000                 4.600000           0.000000
# 50%              30.000000                 4.700000           1.000000
# 75%              34.000000                 4.800000           2.000000
# max              50.000000                 6.000000           3.000000
#
#        multiple_deliveries  Time_taken (min)   distance_km
# count         45584.000000      45584.000000  45584.000000
# mean              1.059385         26.293963      9.714177
# std               0.267766          9.384298      5.572293
# min               1.000000         10.000000      1.463837
# 25%               1.000000         19.000000      4.654185
# 50%               1.000000         26.000000      9.247061
# 75%               1.000000         32.000000     13.659625
# max               3.000000         54.000000     20.942906

# %% [markdown]
# ```For categorical columns, we can do value counts```

# %%
zomato['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Sunny         7898
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Name: count, dtype: int64

# %%
zomato['Type_of_vehicle'].value_counts(normalize = True) # it will give results in percentage of each category
# Out:
# Type_of_vehicle
# motorcycle          0.579787
# scooter             0.335052
# electric_scooter    0.083670
# bicycle             0.001492
# Name: proportion, dtype: float64

# %% [markdown]
# ### <p style="color: red;">UNIVARIATE ANALYSIS</p>

# %% [markdown]
# **countplot**
# <br> **displot**
# <br> **boxplot**
# <br> **kdeplot**
# <br> **piechart**

# %% [markdown]
# ## <p style="color: red;">BIVARIATE ANALYSIS</p>

# %% [markdown]
# **SCATTER**
# <br> **Boxplot**
# <br> **Heatmap**
# <br> **Stripplot**

# %% [markdown]
# ## <p style="color: red;">MULTIVARIATE ANALYSIS</p>

# %% [markdown]
# **Hue**
# <br> **lmplot**
# <br> **subplot**
# <br> **facetgrid**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(zomato['Delivery_person_Age'], kde = True )
plt.show()

# %% [markdown]
# **observation:** we can observe that maximum number of people working are of 30 years age

# %%
# created new column of age which is cut into different bins

zomato['age_bin'] = pd.cut(zomato['Delivery_person_Age'],bins = [18,26,33,40,50])

# %% [markdown]
# **very imp.** binning is very important feature engineering

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
zomato['age_bin'].value_counts()
# Out:
# age_bin
# (26, 33]    17107
# (18, 26]    15112
# (33, 40]    13274
# (40, 50]       53
# Name: count, dtype: int64

# %% [markdown]
# ### distance_km

# %%
sns.displot(zomato['distance_km'], kde = True )
plt.show()

# %% [markdown]
# **observation:** delete the outlier value or replace it with median,

# %%
zomato['distance_km'].max()
# Out:
# 20.94290627698551

# %%
distance_km_median = zomato['distance_km'].median()
distance_km_median
# Out:
# 9.247061166691832

# %% [markdown]
# #### data cleaning: filtering distance km below 1000 km

# %%
zomato=  zomato[zomato['distance_km']<= 100]

# %%
sns.displot(zomato['distance_km'], kde = True )
plt.show()

# %% [markdown]
# **Observation:** We can observe that distance is starting from 1 km and max is 20 km

# %%
zomato['distance_km'].min()
# Out:
# 1.4638371061422368

# %%
zomato['distance_km'].max()
# Out:
# 20.94290627698551

# %% [markdown]
# ### Time_taken (min)

# %%
sns.displot(zomato['Time_taken (min)'], kde = True )
plt.show()

# %% [markdown]
# **observation** there are 2 peak visible, it means Time_taken is divided into 2 groups.
# <br> graph is right skewed, it means there are outliers in higher side of time taken

# %% [markdown]
# ### Ratings

# %%
sns.displot(zomato['Delivery_person_Ratings'], kde = True )
plt.show()

# %% [markdown]
# **observation** Most of the values lie between 4 to 5

# %% [markdown]
# ### countplot

# %%
sns.countplot(x = 'Time_Orderd', data = zomato)
plt.show()

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
sns.countplot(x = 'Vehicle_condition', data = zomato)
plt.show()

# %%
sns.countplot(x = 'multiple_deliveries', data = zomato)
plt.show()

# %%
sns.boxplot(zomato['distance_km'])
plt.show()

# %% [markdown]
# **Observation** minimum value is around 2 Km, median is around 9 Km and max value is approx 21 Km

# %%
sns.boxplot(zomato['Time_taken (min)'])
plt.show()

# %% [markdown]
# **Observation** there are some outliers on the higher end side

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
sns.scatterplot(x = 'distance_km', y = 'Time_taken (min)', data = zomato)
plt.show()

# %%
sns.scatterplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', data = zomato)
plt.show()

# %% [markdown]
# **observation**: As time_taken is increasing, we can observe that ratings is decreasing (observe between 30 to 45 min)

# %%
sns.boxplot(x = 'Time_Orderd', y = 'Time_taken (min)',data = zomato)
plt.show()

# %% [markdown]
# **observation** Highest median is of evening and in moring median is minimum as compare to other time categories

# %%
sns.boxplot(x = 'Road_traffic_density', y = 'Time_taken (min)',data = zomato)
plt.show()

# %% [markdown]
# **observation** Median of time taken is maximum for ```Jam```

# %%
sns.stripplot(x= 'age_bin', y = 'Time_taken (min)',data = zomato)
plt.show()

# %%
sns.heatmap(zomato.corr(numeric_only = True) ,annot=True)
plt.show()

# %% [markdown]
# **Observations**
# <br> There is negative correlation between Time taken and ratings ```(-0.34)```
# <br> There is negative correlation between Time taken and vehicle condition  ```(-0.24)```
# <br> There is positive correlation between Time taken and multiple deliveries ```(0.38)```
# <br> There is positive correlation between Time taken and distance ```(0.32)```
# <br> There is negative correlation between Time taken and ratings ```(-0.34)```

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
plt.figure(figsize= (8,8))
sns.scatterplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' ,data = zomato)
plt.show()

# %% [markdown]
# **Observation** we can observe, between 30 min to 45 Min delivery time, there is sudden drop in ratings.
# <br> All those instances have  **sunny** weather

# %%
sns.boxplot(x = 'multiple_deliveries', y = 'Time_taken (min)',hue = 'Vehicle_condition',data = zomato)
plt.show()

# %% [markdown]
# **Observation** Multiple deliveries impact the time taken, 0 vehicle condition delivery time is higher

# %%
sns.boxplot(x = 'multiple_deliveries', y = 'Delivery_person_Ratings',hue = 'Vehicle_condition',data = zomato)
plt.show()

# %% [markdown]
# **Observation** Multiple deliveries impact the ratings

# %%
plt.figure(figsize= (8,8))
sns.lmplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density',data = zomato)
plt.show()

# %% [markdown]
# **Observation** When road density is low, weather is sunny and  time taken is more than 30 min then customer has given the delivery agent below 3 ratings

# %%
plt.figure(figsize= (8,8))
sns.lmplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density', col= 'multiple_deliveries' , data = zomato)
plt.show()

# %% [markdown]
# **Observation** time taken with multiple delivery is high

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8)) 


sns.scatterplot(x= 'Delivery_person_Ratings', y= 'Time_taken (min)', data=zomato, ax=axes[0, 0])
sns.boxplot(x= 'Vehicle_condition', y= 'Time_taken (min)', data=zomato, ax=axes[0, 1])
sns.boxplot(x= 'multiple_deliveries', y= 'Time_taken (min)', data=zomato, ax=axes[1, 0])
sns.boxplot(x='Type_of_order', y='Time_taken (min)', data=zomato, ax=axes[1, 1])
sns.boxplot(x='age_bin', y='Time_taken (min)', data=zomato, ax=axes[2, 0])
sns.scatterplot(x = 'distance_km', y = 'Time_taken (min)', data = zomato, ax=axes[2, 1])




axes[0, 0].set_title('Delivery_person_Ratings')
axes[0, 1].set_title('Vehicle_condition')
axes[1, 0].set_title('multiple_deliveries')
axes[1, 1].set_title('Type_of_order')
axes[2, 0].set_title('age_bin')
axes[2, 0].set_title('distance_km')




for ax in axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)




plt.tight_layout()


plt.show()
# Out:
# C:\Users\misvi\AppData\Local\Temp\ipykernel_8216\831709073.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\misvi\AppData\Local\Temp\ipykernel_8216\831709073.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\misvi\AppData\Local\Temp\ipykernel_8216\831709073.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\misvi\AppData\Local\Temp\ipykernel_8216\831709073.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\misvi\AppData\Local\Temp\ipykernel_8216\831709073.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\misvi\AppData\Local\Temp\ipykernel_8216\831709073.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %% [markdown]
# **Observation** Multiple deliveries has highest correlation with time taken.
# <br> ratings is affecting time taken
# <br> age bins also affecting the time taken

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
# Using FacetGrid


g = sns.FacetGrid(zomato, col="Weather_conditions", row="Time_Orderd",  height=3, aspect=2)
g.map(sns.boxplot, "Type_of_order", 'Time_taken (min)' ) 


plt.tight_layout()
plt.show()
# Out:
# C:\Users\misvi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
